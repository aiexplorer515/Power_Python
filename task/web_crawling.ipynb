# %% [markdown]
# ## 이해할 기술
# - http 구성 및 동작
# - html/css/(javascript) 구조

# %% [markdown]
# ## HTTP
# - HTML/CSS/javascript/text/csv/json/xml 등등의 text 데이터를 교환 목적
# - binary data 교환
# - 자체적으로 압축이용

# %% [markdown]
# ## RESTFull API(REST API)
# - HTTP의 7가지 메소드 이용 데이터 교환/업데이트

# %% [markdown]
# ![image.png](attachment:2303a6e3-b4cd-4c21-b064-ab4f139b2208.png)

# %%
- get : 바디는 비어있는 상태로 서버에 전달 # 클릭해서 정보를 가져오는 방식
- post

# %% [markdown]
# ![image.png](attachment:7212ee16-c6e0-478a-91b2-75d1388b1a35.png)

# %% [markdown]
# # Query String
# - parameter
# - ? 옵션

# %% [markdown]
# ![image.png](attachment:ac2eedcd-3967-4f68-a29f-b50bb700885c.png)

# %% [markdown]
# ##
# - 200번대, 400번대 코드

# %% [markdown]
# ### data 형식 -> 2차원
# - xml: 'a' -> 20개 부가적 정보 필요
# - html: html 규정(xml에서 파생) a-> 8개 부가적
# - txt: ascii text(unicode text) a
# - csv: ',' 텍스트(이름, 나이, 주소(40)) a -> 3개
# - json: a -> 3개 정도(웹 표준)
# - binary

# %% [markdown]
# 학생정보->세부적 형식/크기/ ....

# %% [markdown]
# ### Json

# %% [markdown]
# ![image.png](attachment:6f74c562-d9b8-4a67-821a-8150deb9cc91.png)

# %% [markdown]
# ![image.png](attachment:e0a8fc92-c722-409d-8168-2e696480a227.png)

# %% [markdown]
#   - 참고 사이트
#   https://www.json.org/json-en.html

# %% [markdown]
# ## xml  # 정보기관 정보 교환시 사용

# %% [markdown]
# ![image.png](attachment:3e7758e0-58ed-459d-90ef-76a0850d5a08.png)

# %% [markdown]
# - body 내용 중점대상
# <!--- id, class 속성--->
#     1. <p id='paragraph'>
#     1. <h1 class='color_title'> : class 공통적인 것
#     1. <!-- CSS Selector
#
# - 무시 대상
# <script>
# <style>
# <link>

# %% [markdown]
# ![image.png](attachment:6324edfa-d5e0-4af0-ad5f-13a7159c8d9e.png)

# %% [markdown]
# ![image.png](attachment:b69aec40-7c2b-470a-b755-6247c0f0d980.png)

# %%
### id는 하나, class는 여러개

# %% [markdown]
# 고강태강사님이 모두에게 02:17 PM
# <!DOCTYPE html>
# <head>
#
# <style>
# .color_title {
#     color: red
# }
# .font_size {
# 	font-size:150%
# }
# p {
# 	text-align:center;
# }
# #paragraph {
# 	text-align:right;
# }
#
# </style>
#
# <title>Page Title</title>
# </head>
#
# <!-- id, class 속성 -->
# <body>
#
#    <h1 class='color_title'>This is a Heading</h1>
#    <h2 class='color_title font_size'>2</h2>
#
#    <img src='https://neilpatel.com/wp-content/uploads/2017/08/image5.png' width=300>
#
#    <p>This is a paragraph1.</p>
#    <p id='paragraph' class='color_title font_size'>This is a paragraph2.</p>
#
# </body>
#
#
# <script >
# </script>
# <style>
#
# </style>
# <link ....>

# %% [markdown]
# ![image.png](attachment:7aea77ef-c510-4e99-a83a-ffefd1cfdbb6.png)

# %% [markdown]
# # 참고사이트
# - https://wikidocs.net/82625
# - http://httpbin.org/

# %% [markdown]
# html 페이지 데이터 유형
# - ul-li
#     - li
# - th, thred
# - tbody
#     - tr, td
# - table

# %% [markdown]
# - 페이지 타이틀 텍스트 분석 필요

# %% [markdown]
# ## urllib, urllib2, urllib3

# %%
# !pip install requests cssselect

# %%
# !pip install bs4

# %%
import requests
from bs4 import BeautifulSoup
