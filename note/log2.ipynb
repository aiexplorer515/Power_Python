# %%
import numpy as np

# %%
p =  1 / 3

# %%
np.log2(p)
# Out:
# -1.5849625007211563

# %% [markdown]
# ![image.png](attachment:68d133e2-6bc7-4c90-a99b-5bc82fdf086b.png)

# %%
#1 전체 스페이드 A
p = 4 / 4
np.log2(p)
# Out:
# 0.0

# %% [markdown]
# ![image.png](attachment:ecffea44-2e01-41ed-b8d5-70adb5405321.png)

# %%
# 스페이드 A 3개 하트 킹1개 
a = 3 / 4
log_a = np.log2(a)
ent_a = -(a * log_a)
b = 1 / 4
log_b = np.log2(b)
ent_b = -(b * log_b)
print (f'a의 Entropy = {ent_a}\nb의 Entropy = {ent_b}\n총Entropy = {ent_a+ent_b}')
# Out:
# a의 Entropy = 0.31127812445913283
# b의 Entropy = 0.5
# 총Entropy = 0.8112781244591328

# %% [markdown]
# ![image.png](attachment:7ff43f11-5368-4e8b-92d1-5fdd959278cf.png)

# %%
# 스페이드 A 2개 하트 킹 2개 
a = 2 / 4
log_a = np.log2(a)
ent_a = -(a * log_a)
b = 2 / 4
log_b = np.log2(b)
ent_b = -(b * log_b)
print (f'a의 Entropy = {ent_a}\nb의 Entropy = {ent_b}\n총Entropy = {ent_a+ent_b}')
# Out:
# a의 Entropy = 0.5
# b의 Entropy = 0.5
# 총Entropy = 1.0

# %% [markdown]
# ![image.png](attachment:df54644c-f68d-4cb6-b7ef-e5c07e7c6ab3.png)

# %%
# 스페이드 A 2개 하트 킹 1개 다이아 5 1개 
a = 2 / 4
log_a = np.log2(a)
ent_a = -(a * log_a)
b = 1 / 4
log_b = np.log2(b)
ent_b = -(b * log_b)
c = 1 / 4
log_c = np.log2(c)
ent_c = -(c * log_c)
print (f'a의 Entropy = {ent_a}\nb의 Entropy = {ent_b}\nc의 Entropy = {ent_c}\n총Entropy = {ent_a+ent_b+ent_c}')
# Out:
# a의 Entropy = 0.5
# b의 Entropy = 0.5
# c의 Entropy = 0.5
# 총Entropy = 1.5

# %% [markdown]
# ![image.png](attachment:efb68cac-d9ed-4534-8ed2-376ec6168982.png)

# %%
# 스페이드 A 4개 하트 킹 4개 다이아 5 4개 
a = 1 / 3
log_a = np.log2(a)
ent_a = -(a * log_a)
b = 1 / 3
log_b = np.log2(b)
ent_b = -(b * log_b)
c = 1 / 3
log_c = np.log2(c)
ent_c = -(c * log_c)
print (f'a의 Entropy = {ent_a}\nb의 Entropy = {ent_b}\nc의 Entropy = {ent_c}\n총Entropy = {ent_a+ent_b+ent_c}')
# Out:
# a의 Entropy = 0.5283208335737187
# b의 Entropy = 0.5283208335737187
# c의 Entropy = 0.5283208335737187
# 총Entropy = 1.584962500721156

# %% [markdown]
# ![image.png](attachment:a57932fc-0244-4ef0-826d-e1b4b555b3c8.png)

# %%
# 스페이드 A 4개 하트 킹 4개 다이아 5 4개 
a = -np.log2(1 / 12)
b = -np.log2(1 / 12)
c = -np.log2(1 / 12)
e = -np.log2(1 / 12)
f = -np.log2(1 / 12)
g = -np.log2(1 / 12)
h = -np.log2(1 / 12)
i = -np.log2(1 / 12)
j = -np.log2(1 / 12)
k = -np.log2(1 / 12)
l = -np.log2(1 / 12)
m = -np.log2(1 / 12)
print (f'a의 Entropy = {a}\nb의 Entropy = {b}\nc의 Entropy = {c}\ne의 Entropy = {e}\nf의 Entropy = {f}\ng의 Entropy = {g}\nh의 Entropy = {h}\ni의 Entropy = {i}\nj의 Entropy = {j}\nk의 Entropy = {k}\nl의 Entropy = {l}\nm의 Entropy = {m}\n총Entropy = {a+b+c+e+f+g+h+i+j+k+l+m}')
# Out:
# a의 Entropy = 3.584962500721156
# b의 Entropy = 3.584962500721156
# c의 Entropy = 3.584962500721156
# e의 Entropy = 3.584962500721156
# f의 Entropy = 3.584962500721156
# g의 Entropy = 3.584962500721156
# h의 Entropy = 3.584962500721156
# i의 Entropy = 3.584962500721156
# j의 Entropy = 3.584962500721156
# k의 Entropy = 3.584962500721156
# l의 Entropy = 3.584962500721156
# m의 Entropy = 3.584962500721156
# 총Entropy = 43.01955000865386

# %%
a = 1 / 12
-np.log2(a) * 12
# Out:
# 43.01955000865387

# %%
ent1 = 3/6 *( - 2/3 * np.log2(2/3) + -1/3*np.log2(1/3))  
ent2 = 3/6 *( - 1/3 * np.log2(1/3) + -2/3*np.log2(2/3))  
1- (ent1+ent2)
# Out:
# 0.08170416594551044

# %%
ent1 = 2/6 *( - 1/2 * np.log2(1/2) + -1/2*np.log2(1/2))  
ent2 = 4/6 *( - 1/2 * np.log2(1/2) + -1/2*np.log2(1/2))  
1- (ent1+ent2)
# Out:
# 0.0
